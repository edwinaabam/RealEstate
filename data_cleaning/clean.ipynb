# %%
import pandas as pd, numpy as numpy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"..\database\alloytower_data.csv")

# %%
data.head()
# Out:
#                                          PROPERTY_ID  \
# 0         5970-Summer-Fest-Dr,-San-Antonio,-TX-78244
# 1  6734-Summer-Fest-105,---106,-San-Antonio,-TX-7...
# 2          6435-Pelican-Coral,-San-Antonio,-TX-78244
# 3       5706-Golf-Hts,-Unit-2,-San-Antonio,-TX-78244
# 4       7323-Highland-Lake-Dr,-San-Antonio,-TX-78244
#
#                                     FORMATTEDADDRESS         CITY STATE  \
# 0         5970 Summer Fest Dr, San Antonio, TX 78244  San Antonio    TX
# 1  6734 Summer Fest 105, # 106, San Antonio, TX 7...  San Antonio    TX
# 2          6435 Pelican Coral, San Antonio, TX 78244  San Antonio    TX
# 3       5706 Golf Hts, Unit 2, San Antonio, TX 78244  San Antonio    TX
# 4       7323 Highland Lake Dr, San Antonio, TX 78244  San Antonio    TX
#
#   COUNTY  ZIPCODE   PROPERTYTYPE         SUBDIVISION  BEDROOMS  BATHROOMS  \
# 0  Bexar    78244  Single Family             SUNRISE       3.0        2.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PROPERTY_ID           10000 non-null  object
#  1   FORMATTEDADDRESS      10000 non-null  object
#  2   CITY                  10000 non-null  object
#  3   STATE                 10000 non-null  object
#  4   COUNTY                9994 non-null   object
#  5   ZIPCODE               10000 non-null  int64
#  6   PROPERTYTYPE          9272 non-null   object
#  7   SUBDIVISION           8461 non-null   object
#  8   BEDROOMS              8832 non-null   float64
#  9   BATHROOMS             8772 non-null   float64
#  10  SQUAREFOOTAGE         9199 non-null   float64
#  11  LOTSIZE               8307 non-null   float64
#  12  YEARBUILT             8914 non-null   float64
#  13  LATITUDE              10000 non-null  float64
# ...
